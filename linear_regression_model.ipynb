# %% [markdown]
# <a href="https://colab.research.google.com/github/suhanibode248/linear_regression/blob/main/linear_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.isnull().sum()
# Out:
# Experience Years    0
# Salary              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
x=df[['Experience Years']]
y=df['Salary']
plt.figure(figsize=(10, 3))
plt.scatter(x,y)
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()

# %%
df.shape
# Out:
# (40, 2)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 96.0233432146844

# %%
lr.predict([[10]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([120653.12763442])

# %%
Year=int(input("Enter the experience in year: "))
salary=lr.predict([[Year]])
print(salary)
# Out:
# Enter the experience in year: 1
# [36002.5779434]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x=df[['Experience Years']]
y=df['Salary']
plt.figure(figsize=(10, 3))
plt.plot(x,lr.predict(x),color='red')
plt.scatter(x,y)
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()
